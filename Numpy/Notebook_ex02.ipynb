# %%
import numpy as np

# %% [markdown]
# ### Create a NumPy array of dimension 300 with zeros without filling it manually

# %%
zero_array = np.zeros(300)
print(zero_array.shape)
# Out:
# (300,)

# %% [markdown]
# ### Reshape it to (3,100)

# %%
zero_array_2d = zero_array.reshape(3, 100)
print(zero_array_2d.shape)
# Out:
# (3, 100)
