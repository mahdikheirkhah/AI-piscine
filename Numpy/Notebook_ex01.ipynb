# %%
import numpy as np

# %%
my_array = np.array([
    10,
    5.7,
    "hi!",
    {"name":"Mahdi", "Age" : 25},
    [1, "2", 2.30],
    (1, "2", 2.30),
    {1, "2", 2.30},
    True         
], dtype = object)

for i in my_array:
    print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'bool'>
