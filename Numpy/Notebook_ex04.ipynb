# %%
import numpy as np

# %% [markdown]
# ### Set the seed to 888

# %%
rng = np.random.default_rng(seed=888)

# %% [markdown]
# ### Generate a one-dimensional array of size 100 with a normal distribution

# %%
one_dim_array = rng.normal(size=100)
print(one_dim_array)
# Out:
# [ 2.63038927e-01  5.02565261e-01 -6.03544630e-01  1.16105320e+00
#   8.98071505e-01 -1.62755391e-01 -9.68181269e-01  5.05120942e-01
#  -2.56207827e-01 -1.69745163e+00  1.69336869e+00  6.32799897e-03
#   3.77968815e-03 -1.64070648e+00 -1.34108723e+00  7.12350868e-01
#  -1.45685554e+00 -7.54516213e-01 -6.85843859e-01 -5.91052010e-01
#   1.37411127e+00 -3.04630902e-01 -6.73853609e-01 -1.80586848e+00
#  -5.40548771e-01 -4.91251392e-01  7.39680108e-01  2.71501625e-01
#  -6.19142920e-02  1.17770521e+00  1.09704152e+00 -1.38911999e+00
#  -6.95696437e-01  8.37534769e-01  9.06290500e-01  8.21394329e-01
#   6.20728542e-01 -2.31346273e-01  3.93687465e-01  1.17078525e+00
#   9.70762290e-02  4.77549317e-01  2.00284960e+00 -4.66757887e-01
#  -3.69496733e-01 -4.61809244e-01  2.08655440e+00  9.88837783e-01
#   1.02189658e+00  6.81389649e-01 -3.79780257e-01  6.79683068e-01
#   8.88184795e-01 -1.08130766e+00 -5.22903695e-01 -6.96775922e-01
#  -7.29571176e-01  1.34755592e+00  3.83166023e-02  1.80026204e+00
#  -8.78028786e-01  3.48549349e-01 -4.42875603e-01  1.49150555e+00
#   6.00351664e-01  3.21523962e+00  1.76695397e+00  7.68280836e-01
#  -9.33697281e-01  1.70947068e+00 -6.48411877e-01 -1.40432444e+00
#   1.41489763e+00  9.26913437e-01  1.15492683e+00 -1.18930237e+00
#  -5.70260600e-01 -1.16756215e+00  3.82689535e-02 -5.68553394e-01
#   1.15962382e-02 -7.43440446e-01  5.69836492e-01 -4.95508924e-01
#   1.26220209e+00  7.16931833e-04 -8.57457981e-01  7.16748975e-01
#   2.30145462e-01  8.81893013e-01  2.79121989e-01 -3.49164172e-01
#   6.29259881e-01 -1.13367167e+00  7.78326005e-01 -1.20662468e+00
#  -9.90049209e-03  1.14224136e+00 -1.24275597e+00  4.74117963e-01]

# %% [markdown]
# ### Generate a two-dimensional array of size 8,8 with random integers from 1 to 10 - both included (same probability for each integer)

# %%
two_dim_array = rng.integers(1, 11, size = (8, 8))
print(two_dim_array)
# Out:
# [[ 4 10  4  2  2  1  3  4]
#  [ 7  2  7  6  6 10  3  3]
#  [10  9  9  7  9  5  9 10]
#  [ 9  4  6 10 10 10  7  7]
#  [ 5  5  7  3  8  5  7  3]
#  [ 4  4  7 10  2 10  4  8]
#  [ 2  8  7  2  2  6  5  4]
#  [ 4  8  8  8  5  1  5  2]]

# %% [markdown]
# ### Generate a three-dimensional of size 4,2,5 array with random integers from 1 to 17 - both included (same probability for each integer)

# %%
three_dim_array = rng.integers(1, 18, size = (4, 2, 5))
print(three_dim_array)
# Out:
# [[[ 8  4  2  8  4]
#   [12 14 14 16 16]]
#
#  [[ 8 12  5  1  7]
#   [13 12  1  1 16]]
#
#  [[ 9 11  4 16 12]
#   [13  8 16  8 13]]
#
#  [[ 5  9  8 13 12]
#   [10 13  5  1 14]]]
