# %% [markdown]
# ## Exercise 0

# %% [markdown]
#  Begin by creating a virtual environment named ex00 that utilizes Python version >= 3.9. Install the required libraries numpy and jupyter. Save the installed packages to a file named requirements.txt, located in the current directory.

# %%
python3 -m venv ex00

source ex00/bin/activate

# %%
pip install --upgrade pip
pip install numpy jupyter
pip freeze > requirements.txt

# %%
jupyter notebook --port 8891
